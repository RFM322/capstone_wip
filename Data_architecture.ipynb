# %% [markdown]
# <img src="images/generalassembly-open-graph.png" width="240" height="240" align="left"/>

# %% [markdown]
# # Data architecture notebook
# **Author: Rodolfo Flores Mendez**
# <br> May 2019 | Chicago, IL.
#
# ### Table of contents
# - [Overview](#ov)
# - [Importing libraries](#imp)
# - [Merging reviews and business data](#me)
# - [Construction of distance matrix](#dist)
# - [Construction of category matrix](#cat)
# - [Script for data architecture as numpy array](#da)

# %% [markdown]
# ### Overview<a id="ov"></a>
# This notebook presents in detail the script used to create the proposed data architecture for businesses in the "area of interest" of "Las Vegas Strip", as explained in the Readme.
#
# There are (4) key steps to compile the desired data architecture:
#
#    - **(1)** Combine the features from multiple dataframes,
#    - **(2)** Construction of distance matrix to mask businesses given a distance criteria (radius of incluence),
#    - **(3)** Construction of a cateogry martix to mask businesses given a business category criteria,
#    - **(4)** Use the distance and category matrix to loop through specific distnace and cateogry bins to build the 4D tensor for the CNN model,
#
# The loop on step (4) to build the data architecture for the CNN model was created using numpy, given that it surpassed the capacity of pandas to manage large sets of multidimensional data.

# %% [markdown]
# ### Importing libraries<a id="imp"></a>
# In this section we outline the initial code needed to run this workbook. If this code returns an error we recommend the reader to verify that the most up to date version of the libraries mentioned below have been installed in their computers. For a guideline on python installation of modules please refer to the __[official documentation](https://docs.python.org/3/installing/)__.

# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Time library
import time

#Setting max rows and columns
pd.set_option('display.max_columns', 10000)
pd.set_option('display.max_rows', 10000)

#Import library for calculating distance between lat and long
import utm

#Import combination and permutation library
from itertools import combinations

# Import Gensim for Wrod2Vec similarity
import gensim

#Import Standard Scaler
from sklearn.preprocessing import StandardScaler
# Out:
# C:\Users\roflo\Anaconda3\lib\site-packages\smart_open\ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')
# C:\Users\roflo\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ### Merging reviews and business data <a id="imp"></a>
# In this section we merge the dataframes that were generated on the preprocessing and data extraction notebooks by business id for the "area of interest" of "Las Vegas Strip".

# %%
#Read the data from the CSV folder, business dataframe created on the data extraction process
df_business = pd.read_csv('./csv_data/business.csv').drop(columns = 'Unnamed: 0')

#Select relevant columns to build the data architecture, these are lat and long for distance metrics (Y dimension),
#categories for similarity metrics (X dimension),
#and the features we want to model with (such as stars, and review count)
df = df_business[['business_id','latitude','longitude','is_open','categories','stars','review_count','city']]
df = df.set_index('business_id') #Set the index to be the business id

#Visualize the head
df.head()
# Out:
#                          latitude   longitude  is_open  \
# business_id
# 1SWheh84yJXfytovILXOAQ  33.522143 -112.018481        0
# QXAEGFB4oINsVuTFxEYKFQ  43.605499  -79.652289        1
# gnKjwL_1w79qoiV3IC_xQQ  35.092564  -80.859132        1
# xvX2CttrVhyG2z1dFg_0xw  33.455613 -112.395596        1
# HhyxOkGAM07SRYtlQ4wMFQ  35.190012  -80.887223        1
#
#                                                                categories  \
# business_id
# 1SWheh84yJXfytovILXOAQ                                  Golf, Active Life
# QXAEGFB4oINsVuTFxEYKFQ  Specialty Food, Restaurants, Dim Sum, Imported...
# gnKjwL_1w79qoiV3IC_xQQ                  Sushi Bars, Restaurants, Japanese
# xvX2CttrVhyG2z1dFg_0xw                      Insurance, Financial Services
# HhyxOkGAM07SRYtlQ4wMFQ  Plumbing, Shopping, Local Services, Home Servi...
#
#                         stars  review_count         city
# business_id
# 1SWheh84yJXfytovILXOAQ    3.0             5      Phoenix
# QXAEGFB4oINsVuTFxEYKFQ    2.5           128  Mississauga
# gnKjwL_1w79qoiV3IC_xQQ    4.0           170    Charlotte
# xvX2CttrVhyG2z1dFg_0xw    5.0             3     Goodyear
# HhyxOkGAM07SRYtlQ4wMFQ    4.0             4    Charlotte

# %% [markdown]
# We will limit the dataframe to the "Las Vegas Strip", which is the area of interest for this particular analysis. The code below limits the dataframe for businesses within such geographical area.

# %% [markdown]
# **Visual representation of the "area of interest" of the "Las Vegas Strip"**
#
# <img src="images/las_Vegas.jpg" width="1000" height="1000" align="left"/>

# %%
#Define lat and long limits
lat_low = 36.092239
lat_up = 36.159071

long_left = -115.234375
long_right = -115.136185

#Mask the dataframe for such lat and long area
mask = (df['latitude']>=lat_low) & (df['latitude']<=lat_up) & (df['longitude']>=long_left) & (df['longitude']<=long_right)
df = df[mask]

#Display the shape
df.shape
# Out:
# (8527, 7)

# %% [markdown]
# As we can see, in this particular instance the number of businesses to analyze is 8,527. We will now standarize the data to be able to run it through the data architecture process and the CNN.

# %%
#Standarize data
ssFeat = ['stars','review_count']
ss = StandardScaler()
df_ss = pd.DataFrame(ss.fit_transform(df[ssFeat]),columns = ssFeat)
df_ss = pd.concat([df_ss,pd.DataFrame(df.index)],axis=1).set_index('business_id')

#Merge the data
df = pd.merge(df.drop(columns = ['stars','review_count']),
              df_ss,
              how='inner',
              left_index=True,
              right_index=True)

#Inspect the shape
df.shape
# Out:
# C:\Users\roflo\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\roflo\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# (8527, 7)

# %%
#Inspect the head
df.head()
# Out:
#                          latitude   longitude  is_open  \
# business_id
# iojTeSaoPuxm4WeCzDUA6w  36.129424 -115.184443        1
# Qwt9lOpplBAZ7JBrgAqI7g  36.138452 -115.198019        1
# R3rss9fkfJxiOK6DueON3w  36.123107 -115.170253        1
# kANF0dbeoW34s2vwh6Umfw  36.125031 -115.225620        0
# gas3YSrKkEcBliUHhnOLTg  36.118157 -115.176430        1
#
#                                                                categories  \
# business_id
# iojTeSaoPuxm4WeCzDUA6w  Car Rental, Windshield Installation & Repair, ...
# Qwt9lOpplBAZ7JBrgAqI7g             Home Services, Real Estate, Apartments
# R3rss9fkfJxiOK6DueON3w                Shopping, Women's Clothing, Fashion
# kANF0dbeoW34s2vwh6Umfw  Fast Food, Food, Restaurants, Ice Cream & Froz...
# gas3YSrKkEcBliUHhnOLTg  Accessories, Shopping, Fashion, Jewelry, Leath...
#
#                              city     stars  review_count
# business_id
# iojTeSaoPuxm4WeCzDUA6w  Las Vegas  0.876344     -0.163222
# Qwt9lOpplBAZ7JBrgAqI7g  Las Vegas -1.658798     -0.290213
# R3rss9fkfJxiOK6DueON3w  Las Vegas  0.369315     -0.290213
# kANF0dbeoW34s2vwh6Umfw  Las Vegas -1.658798     -0.214559
# gas3YSrKkEcBliUHhnOLTg  Las Vegas -0.137713     -0.246982

# %% [markdown]
# Now we will pull in the features from the review dataframe, merge it with this dataframe.

# %%
#Read the df
df_reviews = pd.read_csv('./csv_data/reviews_df.csv').set_index('business_id')
#Visualize the head
df_reviews.head()
# Out:
#                             cool     funny    useful  rev_stars  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw  0.025137  0.022688  0.025372   0.781457
# --DdmeR16TRb3LsjG0ejrQ  0.082353  0.102740  0.071429   0.583333
# --WsruI0IGEoeRmkErU5Gg  0.008824  0.002568  0.011905   0.921875
# --z7PM8AGaJP0aBmGMY7RA  0.007059  0.008219  0.020952   0.950000
# -0BxAGlIk5DJAGVkpqBXxg  0.014439  0.015878  0.017857   0.494318
#
#                         positive_comments  negative_comments       age  \
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw           4.421910           0.798729  2.149817
# --DdmeR16TRb3LsjG0ejrQ          -0.279587          -0.295701 -0.035132
# --WsruI0IGEoeRmkErU5Gg          -0.259057          -0.232561 -1.081193
# --z7PM8AGaJP0aBmGMY7RA          -0.226794          -0.274654 -0.008271
# -0BxAGlIk5DJAGVkpqBXxg          -0.200398          -0.064187  1.630943
#
#                         t_last_c  t_comments  polarity  subjectivity
# business_id
# --9e1ONYQuAa-CB_Rrw7Tw -0.652387    2.577041  0.344247      0.590875
# --DdmeR16TRb3LsjG0ejrQ  1.267161   -0.800340  0.137890      0.506403
# --WsruI0IGEoeRmkErU5Gg -0.066477   -1.057948  0.229604      0.543175
# --z7PM8AGaJP0aBmGMY7RA -0.523299    0.307380  0.233854      0.476470
# -0BxAGlIk5DJAGVkpqBXxg -0.502538    1.959645  0.199909      0.574302

# %%
#Inspect the shape
df_reviews.shape
# Out:
# (8527, 11)

# %%
#Merge both dataframes
df= pd.merge(df,
             df_reviews,
             how='inner',
             left_index=True,
             right_index=True)

df['is_closed'] = df['is_open'].apply(lambda x: 1 if x==0 else 0)
#Check the shape
df.shape
# Out:
# (8527, 19)

# %%
#Inspect the head
df.head()
# Out:
#                          latitude   longitude  is_open  \
# business_id
# iojTeSaoPuxm4WeCzDUA6w  36.129424 -115.184443        1
# Qwt9lOpplBAZ7JBrgAqI7g  36.138452 -115.198019        1
# R3rss9fkfJxiOK6DueON3w  36.123107 -115.170253        1
# kANF0dbeoW34s2vwh6Umfw  36.125031 -115.225620        0
# gas3YSrKkEcBliUHhnOLTg  36.118157 -115.176430        1
#
#                                                                categories  \
# business_id
# iojTeSaoPuxm4WeCzDUA6w  Car Rental, Windshield Installation & Repair, ...
# Qwt9lOpplBAZ7JBrgAqI7g             Home Services, Real Estate, Apartments
# R3rss9fkfJxiOK6DueON3w                Shopping, Women's Clothing, Fashion
# kANF0dbeoW34s2vwh6Umfw  Fast Food, Food, Restaurants, Ice Cream & Froz...
# gas3YSrKkEcBliUHhnOLTg  Accessories, Shopping, Fashion, Jewelry, Leath...
#
#                              city     stars  review_count      cool     funny  \
# business_id
# iojTeSaoPuxm4WeCzDUA6w  Las Vegas  0.876344     -0.163222  0.050980  0.005327
# Qwt9lOpplBAZ7JBrgAqI7g  Las Vegas -1.658798     -0.290213  0.007059  0.008219
# R3rss9fkfJxiOK6DueON3w  Las Vegas  0.369315     -0.290213  0.042353  0.032877
# kANF0dbeoW34s2vwh6Umfw  Las Vegas -1.658798     -0.214559  0.022460  0.024907
# gas3YSrKkEcBliUHhnOLTg  Las Vegas -0.137713     -0.246982  0.011765  0.011742
#
#                           useful  rev_stars  positive_comments  \
# business_id
# iojTeSaoPuxm4WeCzDUA6w  0.077601   0.842593          -0.147605
# Qwt9lOpplBAZ7JBrgAqI7g  0.023810   0.300000          -0.291319
# R3rss9fkfJxiOK6DueON3w  0.023810   0.700000          -0.285453
# kANF0dbeoW34s2vwh6Umfw  0.026696   0.310606          -0.244392
# gas3YSrKkEcBliUHhnOLTg  0.015873   0.666667          -0.238526
#
#                         negative_comments       age  t_last_c  t_comments  \
# business_id
# iojTeSaoPuxm4WeCzDUA6w          -0.232561 -0.127313 -0.644360    0.259535
# Qwt9lOpplBAZ7JBrgAqI7g          -0.232561 -1.381839 -0.616790   -1.031203
# R3rss9fkfJxiOK6DueON3w          -0.274654  1.280116  0.673612    0.893604
# kANF0dbeoW34s2vwh6Umfw           0.020000  1.128602  0.248548    0.996227
# gas3YSrKkEcBliUHhnOLTg          -0.274654 -0.839853 -0.532271   -0.531763
#
#                         polarity  subjectivity  is_closed
# business_id
# iojTeSaoPuxm4WeCzDUA6w  0.266891      0.575435          0
# Qwt9lOpplBAZ7JBrgAqI7g -0.004517      0.446689          0
# R3rss9fkfJxiOK6DueON3w -0.024604      0.580472          0
# kANF0dbeoW34s2vwh6Umfw  0.039826      0.530649          1
# gas3YSrKkEcBliUHhnOLTg  0.259513      0.543087          0

# %% [markdown]
# ### Construction of distance matrix<a id="dist"></a>
#
# In this section the code to create the distance matrix is detailed.

# %%
#Create columns that convert the lat and long to UTM in order to compute Euclidean distance
values = [utm.from_latlon(x,y)[0] for (x,y) in zip(df['latitude'],df['longitude'])]
df['UTM1'] = values
values = [utm.from_latlon(x,y)[1] for (x,y) in zip(df['latitude'],df['longitude'])]
df['UTM2'] = values

#Convert the columns to numpy arrays
lats = df['UTM1'].values
lons = df['UTM2'].values

#Calculate the absolute difference between all the elements of the vector
dlats = np.abs(lats[:, None] - lats[None, :])
dlongs = np.abs(lons[:, None] - lons[None, :])

#Compute Euclidean distance and store on a distance matrix where each row is a vector of the distance of a specific business
#to all the other businesses in the dataset
distances = np.sqrt((dlats)**2 + (dlongs)**2)

#Display the distances shape
distances.shape
# Out:
# (8527, 8527)

# %%
#Create a sign matrix to update the distance matrix based on north to south orientation
signs = np.sign(np.array(lats[:, None] - lats[None, :]))

distances = np.multiply(distances,signs)

# %%
#Check again the shape
distances.shape
# Out:
# (8527, 8527)

# %% [markdown]
# ### Construction of category  matrix<a id="cat"></a>
#
# In this section the code to create the category matrix is detailed.It displays if a given business pertains to a specific category, and then uses this output to create category mask of the same dimensions as the distance martix.

# %%
#Expand the Categories column into a dummy field
#First obtain a list of all the categories that exist
categories = []
for x in df['categories']:
    if type(x)==float:
        continue
    else:
        categories.extend(x.split(','))

#Clean white spaces
categories = [x.strip() for x in categories]
#Create a list with unique items
categories = [str(x) for x in set(categories)]

#Create a dataframe
frame = []
for x in df['categories']:
    values=[]
    try:
        for cat in categories:
            if cat in [x.strip() for x in x.split(',')]:
                values.append(1)
            else:
                values.append(0)
    except:
        for cat in categories:
            values.append(0)
    
    frame.append(values)

#Store in a DataFrame
df_categories = pd.DataFrame(frame, columns = categories).fillna(0)

#Add the business id column
df_categories.index=df.index
df_categories = df_categories.astype(float)

# %%
#Check a vectors head
df_categories['Restaurants'].head()
# Out:
# business_id
# iojTeSaoPuxm4WeCzDUA6w    0.0
# Qwt9lOpplBAZ7JBrgAqI7g    0.0
# R3rss9fkfJxiOK6DueON3w    0.0
# kANF0dbeoW34s2vwh6Umfw    1.0
# gas3YSrKkEcBliUHhnOLTg    0.0
# Name: Restaurants, dtype: float64

# %% [markdown]
# In the following lines of code we will loop through the different distance and category bins to build the data architecure.

# %%
#In order to define the distance bins, we need to look at the distribution of the distance.
np.min(distances)
# Out:
# -11109.495594971773

# %%
np.max(distances)
# Out:
# 11109.495594971773

# %% [markdown]
# 11km is the limit for north and south distance. Hennce we will define bins that do not exceed this limits. We also need to define the similarity between the categories, in order to order the categories from middle to outer based on similarity. For this task we will use the Word2Vec library gesmin and train it with the wikipedia archive.

# %%
# Start timer.
t0 = time.time()
# Import word vectors into "model."
model = gensim.models.KeyedVectors.load_word2vec_format('lexvec.enwiki+newscrawl.300d.W.pos.vectors.gz')
# Print results of timer.
print(time.time() - t0)
# Out:
# 142.22134399414062

# %%
#Get list of categories
categories = []
for x in df['categories']:
    if type(x)==float:
        continue
    else:
        categories.extend(x.split(','))

#Clean white spaces
categories = [x.strip() for x in categories]
#Create a list with unique items
categories = [str(x) for x in set(categories)] 

#Compute similarity
similarity = []
for x in categories:
    try:
        similarity.append([x,model.n_similarity('restaurant',[x.replace('&','').lower()])])
    except:
        similarity.append([x,'NaN'])

#Store in a dataframe
df_similarity = pd.DataFrame(similarity,
                             columns=['Categories','Similarity'])

df_similarity['Similarity'] = df_similarity['Similarity'].astype(float)

# %%
#Display sorted dataframe
df_similarity.sort_values(by='Similarity',ascending=False)
# Out:
#                               Categories  Similarity
# 262                                 Soup    0.144928
# 596                              Propane    0.141016
# 665                               Tiling    0.140095
# 226                                Cuban    0.128176
# 153                              Turkish    0.126016
# 110                           Vietnamese    0.125647
# 933                                 Used    0.120434
# 168                        Pediatricians    0.118427
# 772                            Argentine    0.114099
# 525                              Mexican    0.113556
# 379                                 Food    0.111397
# 631                                Ramen    0.110374
# 514                              Bowling    0.110190
# 214                               Siding    0.107519
# 366                                Books    0.107167
# 716                          Advertising    0.102858
# 390                                Adult    0.097354
# 48                              Southern    0.096611
# 86                                 Vegan    0.094132
# 35                                 Pizza    0.092882
# 88                                Afghan    0.091968
# 536                             Bakeries    0.090897
# 288                                Wraps    0.089462
# 846                                Reiki    0.087398
# 501                           Venezuelan    0.087155
# 222                               Tennis    0.084241
# 140                            Mongolian    0.084092
# 597                              Airsoft    0.083588
# 872                               Bagels    0.083098
# 506                              Spanish    0.082223
# 858                              Burgers    0.081299
# 464                               Bridal    0.079756
# 47                             Marketing    0.079401
# 899                             Honduran    0.078850
# 183                               Clowns    0.076304
# 756                              Pilates    0.076179
# 100                   Gastroenterologist    0.074184
# 113                                 Golf    0.073882
# 2                                   Thai    0.073460
# 885                            Colombian    0.072653
# 873                              Lawyers    0.072280
# 206                           Bartenders    0.071317
# 784                              Russian    0.070979
# 735                                 Hats    0.070656
# 171                                Irish    0.070578
# 195                         Cheerleading    0.070423
# 717                               Tattoo    0.070285
# 241                              Hospice    0.069817
# 737                               French    0.068854
# 518                              Chinese    0.068425
# 3                                Doctors    0.068004
# 189                            Pakistani    0.067671
# 17                              Macarons    0.067647
# 474                           Gymnastics    0.067317
# 254                              Fashion    0.066732
# 560                            Investing    0.064994
# 355                              Karaoke    0.064443
# 416                                 Poke    0.063592
# 71                              Handyman    0.062996
# 750                            Insurance    0.062099
# 412                           Mattresses    0.061949
# 725                               Donuts    0.061915
# 670                                Delis    0.061302
# 329                               German    0.060610
# 421                              Buffets    0.060420
# 227                               Kosher    0.060274
# 345                                Halal    0.059475
# 758                              Noodles    0.059162
# 591                             Lingerie    0.058970
# 237                               Waxing    0.058726
# 69                              Hawaiian    0.058426
# 130                           Bookstores    0.057629
# 9                                Italian    0.057149
# 711                          Steakhouses    0.057052
# 109                                 Mags    0.056694
# 648                       Transportation    0.056317
# 853                                Bikes    0.056305
# 116                              Waffles    0.056040
# 699                            Cantonese    0.055945
# 265                             Cupcakes    0.055476
# 594                              British    0.054898
# 38                              Pretzels    0.054854
# 902                             Psychics    0.054439
# 786                              Parking    0.054187
# 728                                Tacos    0.053558
# 279                               Korean    0.053530
# 677                       Fingerprinting    0.052583
# 765                          Courthouses    0.052285
# 568                              Izakaya    0.051721
# 945                           Drugstores    0.051665
# 151                   Telecommunications    0.051588
# 349                            Gardeners    0.051338
# 473                                Taxis    0.050241
# 763                           Sandwiches    0.049970
# 61                              Lebanese    0.049899
# 789                              Jewelry    0.049588
# 224                          Prosthetics    0.049478
# 68                                  Yoga    0.049008
# 484                        Waterproofing    0.048290
# 125                              Grocery    0.047852
# 380                             Trainers    0.047650
# 42                                  Beer    0.047640
# 896                            Computers    0.047310
# 531                           Vegetarian    0.047062
# 904                          Restaurants    0.046543
# 91                             Empanadas    0.046160
# 193                            Malaysian    0.044742
# 787                             Japanese    0.044651
# 637                           Teppanyaki    0.044442
# 469                              Framing    0.044397
# 792                             Airports    0.043953
# 534                              Barbers    0.043919
# 263                                Tires    0.043828
# 529                              Butcher    0.043471
# 382                             Pharmacy    0.043389
# 847                              African    0.043168
# 830                              Belgian    0.043087
# 775                            Ethiopian    0.042691
# 692                           Salvadoran    0.042556
# 768                             Egyptian    0.042437
# 905                            Brazilian    0.041730
# 934                               Soccer    0.041161
# 67                         Cardiologists    0.040915
# 606                             Plumbing    0.040651
# 913                            Utilities    0.040571
# 200                          Contractors    0.040562
# 154                           Preschools    0.040561
# 324                                Greek    0.040297
# 338                                 Pubs    0.040063
# 844                             Swimwear    0.039995
# 507                          Bookkeepers    0.039929
# 731                             Peruvian    0.038160
# 645                         Cheesesteaks    0.038056
# 588                                Wills    0.037661
# 322                               Gelato    0.037496
# 353                             Shopping    0.037214
# 580                        Veterinarians    0.036463
# 575                          Campgrounds    0.036391
# 92                                  Gyms    0.035843
# 719                              Seafood    0.034682
# 814                          Caricatures    0.034093
# 590                            Festivals    0.033890
# 74                           Wholesalers    0.033739
# 12                            Portuguese    0.033539
# 283                             Barbeque    0.033282
# 339                         Optometrists    0.033226
# 914                           Sunglasses    0.033178
# 455                              Watches    0.032604
# 621                            Mediators    0.032436
# 303                                Honey    0.031438
# 636                               Karate    0.030993
# 494                             Midwives    0.030945
# 293                                 Bars    0.030910
# 368                          Playgrounds    0.030844
# 527                        Nutritionists    0.030569
# 93                                Movers    0.030360
# 877                      Rheumatologists    0.029884
# 701                             Filipino    0.029466
# 549                            Engraving    0.029454
# 643                              Laotian    0.029205
# 785                               Diners    0.029147
# 617                        Mediterranean    0.028862
# 447                              Archery    0.028672
# 87                                Boxing    0.028665
# 908                             Flooring    0.028277
# 213                             Antiques    0.028189
# 672                           Laundromat    0.028049
# 909                     Ophthalmologists    0.027686
# 454                               Cinema    0.027645
# 942                          Audiologist    0.027632
# 305                              Tickets    0.026919
# 459                              Cabaret    0.026305
# 142                              Arabian    0.026143
# 941                             Desserts    0.026131
# 620                            Caribbean    0.026075
# 949                           Carpenters    0.026059
# 370                            Taiwanese    0.025592
# 22                           Neurologist    0.025558
# 26                            Brasseries    0.025466
# 143                        Psychiatrists    0.024937
# 486                            Breweries    0.024840
# 721                            Taekwondo    0.024780
# 937                              Resorts    0.023789
# 446                         Electricians    0.023575
# 369                                Tours    0.023217
# 423                          Podiatrists    0.022926
# 868                           Architects    0.022380
# 565                              Hostels    0.022197
# 683                             Costumes    0.022056
# 686                            Education    0.022030
# 95                               Falafel    0.021776
# 426                              Roofing    0.021519
# 799                          Landscaping    0.021307
# 90                           Accessories    0.021248
# 307                             Shutters    0.020585
# 240                               Tuscan    0.020269
# 916                                Cafes    0.020140
# 465                          Astrologers    0.019342
# 783                             Dentists    0.018942
# 627                                 Rugs    0.018892
# 45                             Skydiving    0.018189
# 892                         Orthopedists    0.018153
# 73                             Hospitals    0.017957
# 54                              Florists    0.017805
# 538                          Hydroponics    0.017238
# 424                                Buses    0.016945
# 569                         Hydrotherapy    0.016182
# 572                              Lounges    0.015997
# 127                            Nightlife    0.015877
# 173                             Moroccan    0.015638
# 857                                  DJs    0.015564
# 441                               Towing    0.014925
# 633                              Casinos    0.014879
# 836                          Electronics    0.014751
# 516                               Fondue    0.014368
# 223                              Massage    0.014341
# 76                                  Pets    0.014026
# 881                               Hotels    0.013101
# 136                                Limos    0.012995
# 451                        Psychologists    0.012284
# 232                             Surgeons    0.011876
# 167                         Shanghainese    0.011764
# 256                            Magicians    0.011648
# 776                           Synagogues    0.011284
# 491                              Tanning    0.010500
# 485                               Hiking    0.009842
# 340                               Indian    0.008849
# 723                                Parks    0.008367
# 410                         Delicatessen    0.007715
# 381                            Orthotics    0.007635
# 81                               Boating    0.006551
# 660                            Carpeting    0.004406
# 0                               Uniforms    0.004274
# 794                           Apartments    0.003768
# 437                            Ukrainian    0.003109
# 375                            Paintball    0.003018
# 28                            Kickboxing    0.002954
# 730                                 Wigs    0.002805
# 457                          Coffeeshops    0.002138
# 689                              Surfing    0.002119
# 66                                  Zoos    0.002089
# 790                           Appliances    0.001105
# 604                         Condominiums    0.000986
# 866                             Painters    0.000182
# 7                                 Polish   -0.000360
# 862                        Toxicologists   -0.000365
# 357                          Accountants   -0.001009
# 871                             Churches   -0.001015
# 458                             Notaries   -0.001372
# 546                           Automotive   -0.001569
# 129                          Reflexology   -0.002387
# 895                                Salad   -0.002514
# 347                               Saunas   -0.003213
# 766                            Aquariums   -0.003951
# 644                              Luggage   -0.004567
# 315                             Piercing   -0.005447
# 282                          Matchmakers   -0.006665
# 652                              Rolfing   -0.008326
# 584                            Libraries   -0.008995
# 602                              Beaches   -0.009079
# 37                         Videographers   -0.009648
# 259                              Arcades   -0.010002
# 373                        Chiropractors   -0.011055
# 267                             Wineries   -0.011404
# 244                          Singaporean   -0.013152
# 10                               Museums   -0.013442
# 795                              Awnings   -0.013521
# 56                             Musicians   -0.013624
# 175                             Caterers   -0.015520
# 673                    Anesthesiologists   -0.021047
# 301                        Photographers   -0.022364
# 729                           Irrigation   -0.025710
# 663                          Acupuncture   -0.028614
# 545                               Trains   -0.029665
# 655                            Cabinetry   -0.031172
# 252                        Orthodontists   -0.031530
# 930                           Gastropubs   -0.031785
# 170                               Trusts   -0.035239
# 166                             Szechuan   -0.038574
# 669                           Officiants   -0.042055
# 553                            Ziplining   -0.043471
# 803                             Gunsmith   -0.049824
# 1                            Hair Salons         NaN
# 4                            Gluten-Free         NaN
# 5                     General Litigation         NaN
# 6                         Organic Stores         NaN
# 8                Religious Organizations         NaN
# 11                  Refinishing Services         NaN
# 13      Heating & Air Conditioning\/HVAC         NaN
# 14                        Life Insurance         NaN
# 15                          Pet Services         NaN
# 16                     Video Game Stores         NaN
# 18                      Wholesale Stores         NaN
# 19                         Barre Classes         NaN
# 20                    Auto Customization         NaN
# 21                Party & Event Planning         NaN
# 23                   Diagnostic Services         NaN
# 24         Photography Stores & Services         NaN
# 25                          Medical Spas         NaN
# 27                         Fabric Stores         NaN
# 29                   Carpet Installation         NaN
# 30                       Immigration Law         NaN
# 31                             Bar Crawl         NaN
# 32                             Skin Care         NaN
# 33           Water Purification Services         NaN
# 34                  Divorce & Family Law         NaN
# 36                        Auto Detailing         NaN
# 39                     Community Centers         NaN
# 40                        Product Design         NaN
# 41                    Party Bike Rentals         NaN
# 43                    Motorcycle Dealers         NaN
# 44                   Photo Booth Rentals         NaN
# 46                   Boudoir Photography         NaN
# 49               Countertop Installation         NaN
# 50                    Real Estate Agents         NaN
# 51                            Club Crawl         NaN
# 52                       Motorcycle Gear         NaN
# 53                        Tattoo Removal         NaN
# 55                       Donation Center         NaN
# 57                      Used Car Dealers         NaN
# 58                         Leather Goods         NaN
# 59                    Recreation Centers         NaN
# 60                      Nail Technicians         NaN
# 62               Beach Equipment Rentals         NaN
# 63                       Flowers & Gifts         NaN
# 64                       Septic Services         NaN
# 65            Assisted Living Facilities         NaN
# 70                           Gold Buyers         NaN
# 72                        Maternity Wear         NaN
# 75                        Radio Stations         NaN
# 77                            Home Decor         NaN
# 78                        Makeup Artists         NaN
# 79                        Men's Clothing         NaN
# 80                        Tabletop Games         NaN
# 82                          Social Clubs         NaN
# 83                           Title Loans         NaN
# 84                   Private Jet Charter         NaN
# 85                        Middle Eastern         NaN
# 89                  Shared Office Spaces         NaN
# 94                          Local Flavor         NaN
# 96                           Sports Bars         NaN
# 97                  Gemstones & Minerals         NaN
# 98                          Escape Games         NaN
# 99                              Hot Dogs         NaN
# 101                     Buddhist Temples         NaN
# 102                         Martial Arts         NaN
# 103                    Ear Nose & Throat         NaN
# 104                       Kitchen & Bath         NaN
# 105                          Art Classes         NaN
# 106                  Country Dance Halls         NaN
# 107                         Coffee & Tea         NaN
# 108                           Mass Media         NaN
# 111                      Real Estate Law         NaN
# 112                           Body Shops         NaN
# 114                      Glass & Mirrors         NaN
# 115                        Machine Shops         NaN
# 117                         Outdoor Gear         NaN
# 118                         Pet Training         NaN
# 119             Bike Repair\/Maintenance         NaN
# 120                 Arts & Entertainment         NaN
# 121                         Tanning Beds         NaN
# 122                         Guest Houses         NaN
# 123                         Ticket Sales         NaN
# 124                       Legal Services         NaN
# 126                  Do-It-Yourself Food         NaN
# 128                    Pet Waste Removal         NaN
# 131       Audio\/Visual Equipment Rental         NaN
# 132                      Patio Coverings         NaN
# 133                           Signmaking         NaN
# 134                           Meat Shops         NaN
# 135                       Fences & Gates         NaN
# 137              Party Equipment Rentals         NaN
# 138                       Souvenir Shops         NaN
# 139                     Cannabis Clinics         NaN
# 141                          Urgent Care         NaN
# 144                     Eyebrow Services         NaN
# 145                 Educational Services         NaN
# 146                  Employment Agencies         NaN
# 147                       Wine & Spirits         NaN
# 148              Misting System Services         NaN
# 149                          Car Dealers         NaN
# 150                 Landscape Architects         NaN
# 152                    Local Fish Stores         NaN
# 155                   Appraisal Services         NaN
# 156                       Golf Equipment         NaN
# 157                       Opera & Ballet         NaN
# 158                     Party Characters         NaN
# 159            Professional Sports Teams         NaN
# 160                        Spray Tanning         NaN
# 161                    Sleep Specialists         NaN
# 162                            Fast Food         NaN
# 163          Holiday Decorating Services         NaN
# 164                          Yelp Events         NaN
# 165                       Private Tutors         NaN
# 169                     Test Preparation         NaN
# 172                Cannabis Dispensaries         NaN
# 174            Swimming Lessons\/Schools         NaN
# 176                      Artificial Turf         NaN
# 177                  Estate Planning Law         NaN
# 178                       Spiritual Shop         NaN
# 179               Naturopathic\/Holistic         NaN
# 180                    Art Space Rentals         NaN
# 181                    Stadiums & Arenas         NaN
# 182                  Television Stations         NaN
# 184                           Sushi Bars         NaN
# 185                    Farming Equipment         NaN
# 186                       Grout Services         NaN
# 187                       Herbs & Spices         NaN
# 188                          Shoe Repair         NaN
# 190          Fitness\/Exercise Equipment         NaN
# 191                    Currency Exchange         NaN
# 192           Medical Cannabis Referrals         NaN
# 194                Rehabilitation Center         NaN
# 196             Mobile Phone Accessories         NaN
# 197                           Piano Bars         NaN
# 198                Auto Parts & Supplies         NaN
# 199    Screen Printing\/T-Shirt Printing         NaN
# 201                    Metal Fabricators         NaN
# 202                   Laboratory Testing         NaN
# 203                           Gift Shops         NaN
# 204                         Ice Delivery         NaN
# 205                     Physical Therapy         NaN
# 207                      Cultural Center         NaN
# 208                      Modern European         NaN
# 209                   Montessori Schools         NaN
# 210                          Car Brokers         NaN
# 211                        Tree Services         NaN
# 212                    Coffee Roasteries         NaN
# 215                          Safe Stores         NaN
# 216                  New Mexican Cuisine         NaN
# 217                       Discount Store         NaN
# 218                             Day Spas         NaN
# 219                      Seafood Markets         NaN
# 220                   Elementary Schools         NaN
# 221                      Prosthodontists         NaN
# 225               Pool & Hot Tub Service         NaN
# 228                         Post Offices         NaN
# 229        Vocational & Technical School         NaN
# 230                   Estate Liquidation         NaN
# 231                     Balloon Services         NaN
# 233                       Car Inspectors         NaN
# 234                         Clock Repair         NaN
# 235                    First Aid Classes         NaN
# 236                      Tasting Classes         NaN
# 238                          Boat Repair         NaN
# 239                    Vascular Medicine         NaN
# 242              Colleges & Universities         NaN
# 243                       Water Delivery         NaN
# 245                  Tapas\/Small Plates         NaN
# 246                           Car Rental         NaN
# 247                       Sporting Goods         NaN
# 248                   ATV Rentals\/Tours         NaN
# 249                          Dog Walkers         NaN
# 250         Public Services & Government         NaN
# 251        Middle Schools & High Schools         NaN
# 253                              Dim Sum         NaN
# 255                         Art Supplies         NaN
# 257                           Food Court         NaN
# 258                   Breakfast & Brunch         NaN
# 260                 Alternative Medicine         NaN
# 261                         Chicken Shop         NaN
# 264                      Hair Extensions         NaN
# 266                International Grocery         NaN
# 268                            Muay Thai         NaN
# 269                       Street Vendors         NaN
# 270                     Retirement Homes         NaN
# 271            Home Network Installation         NaN
# 272                   Solar Installation         NaN
# 273                    Air Duct Cleaning         NaN
# 274               Juice Bars & Smoothies         NaN
# 275            Ice Cream & Frozen Yogurt         NaN
# 276                          Bingo Halls         NaN
# 277                      Roof Inspectors         NaN
# 278                         Asian Fusion         NaN
# 280                   Grilling Equipment         NaN
# 281                        Lawn Services         NaN
# 284                      Talent Agencies         NaN
# 285                      Emergency Rooms         NaN
# 286                       Nanny Services         NaN
# 287                      Adult Education         NaN
# 289                  Restaurant Supplies         NaN
# 290                         Horse Racing         NaN
# 291               Veterans Organizations         NaN
# 292                Traffic Ticketing Law         NaN
# 294                       Health Markets         NaN
# 295                           Street Art         NaN
# 296                        Fencing Clubs         NaN
# 297                     Laundry Services         NaN
# 298                      Driving Schools         NaN
# 299                       Cardio Classes         NaN
# 300                Circuit Training Gyms         NaN
# 302         Couriers & Delivery Services         NaN
# 304                     Wildlife Control         NaN
# 306                            Feng Shui         NaN
# 308              Commercial Truck Repair         NaN
# 309                  Auto Loan Providers         NaN
# 310                    Wine Tasting Room         NaN
# 311                     Furniture Repair         NaN
# 312        Lighting Fixtures & Equipment         NaN
# 313                Hearing Aid Providers         NaN
# 314        IT Services & Computer Repair         NaN
# 316                Fitness & Instruction         NaN
# 317                        Hydro-jetting         NaN
# 318                          Art Schools         NaN
# 319                      Wedding Chapels         NaN
# 320              Real Estate Photography         NaN
# 321           Motorsport Vehicle Repairs         NaN
# 323                      Screen Printing         NaN
# 325                  Mobile Phone Repair         NaN
# 326                       Personal Chefs         NaN
# 327                    Internal Medicine         NaN
# 328                 Windows Installation         NaN
# 330                  Transmission Repair         NaN
# 331                           Acai Bowls         NaN
# 332                      Family Practice         NaN
# 333                Coffee & Tea Supplies         NaN
# 334                          Dance Clubs         NaN
# 335                        Cajun\/Creole         NaN
# 336                    Men's Hair Salons         NaN
# 337             Team Building Activities         NaN
# 341                    Plus Size Fashion         NaN
# 342                        Data Recovery         NaN
# 343                           Fuel Docks         NaN
# 344                    Masonry\/Concrete         NaN
# 346                      Hotels & Travel         NaN
# 348                   Diagnostic Imaging         NaN
# 350                           Pet Stores         NaN
# 351        High Fidelity Audio Equipment         NaN
# 352                       Battery Stores         NaN
# 354                         Hair Removal         NaN
# 356                      Hardware Stores         NaN
# 358                      Christmas Trees         NaN
# 359                 Embroidery & Crochet         NaN
# 360                         Music Venues         NaN
# 361                      Clothing Rental         NaN
# 362            Home Theatre Installation         NaN
# 363                         Business Law         NaN
# 364               Customized Merchandise         NaN
# 365                        Hair Stylists         NaN
# 367         Television Service Providers         NaN
# 371                      Animal Shelters         NaN
# 372                     Language Schools         NaN
# 374             Door Sales\/Installation         NaN
# 376             Outdoor Furniture Stores         NaN
# 377        Funeral Services & Cemeteries         NaN
# 378                  Oil Change Stations         NaN
# 383                     Bespoke Clothing         NaN
# 384                  Weight Loss Centers         NaN
# 385                        Imported Food         NaN
# 386                Baby Gear & Furniture         NaN
# 387                   Fireplace Services         NaN
# 388                   Financial Advising         NaN
# 389                          TV Mounting         NaN
# 391               Personal Care Services         NaN
# 392                Child Care & Day Care         NaN
# 393                         Boat Dealers         NaN
# 394                               Tui Na         NaN
# 395                        Vinyl Records         NaN
# 396                      Pet Photography         NaN
# 397                  Eyewear & Opticians         NaN
# 398                   Laser Hair Removal         NaN
# 399                          Auto Repair         NaN
# 400                    Racing Experience         NaN
# 401                    Neuropathologists         NaN
# 402                   Car Window Tinting         NaN
# 403                            Wine Bars         NaN
# 404                           Vape Shops         NaN
# 405                            Tea Rooms         NaN
# 406                 Translation Services         NaN
# 407                           Toy Stores         NaN
# 408                         Flea Markets         NaN
# 409                      Drive-Thru Bars         NaN
# 411                      Scavenger Hunts         NaN
# 413                          Ethnic Food         NaN
# 414                      Decks & Railing         NaN
# 415                      Sports Medicine         NaN
# 417              Environmental Abatement         NaN
# 418                       Piano Services         NaN
# 419                      Carpet Cleaning         NaN
# 420                 Garage Door Services         NaN
# 422                     Firearm Training         NaN
# 425                         Fish & Chips         NaN
# 427                         Sports Clubs         NaN
# 428                          Print Media         NaN
# 429                        Chicken Wings         NaN
# 430             Passport & Visa Services         NaN
# 431                    General Dentistry         NaN
# 432                         Beer Gardens         NaN
# 433                         Pet Groomers         NaN
# 434                           Life Coach         NaN
# 435                      Cycling Classes         NaN
# 436                     Payroll Services         NaN
# 438                        DIY Auto Shop         NaN
# 439                    Home Organization         NaN
# 440                       Dinner Theater         NaN
# 442                         Trivia Hosts         NaN
# 443                      Bed & Breakfast         NaN
# 444                         Gas Stations         NaN
# 445               Vacation Rental Agents         NaN
# 448           Ultrasound Imaging Centers         NaN
# 449                           Boot Camps         NaN
# 450                     Shipping Centers         NaN
# 452                       Acne Treatment         NaN
# 453                Supernatural Readings         NaN
# 456                              Qi Gong         NaN
# 460                         Bike Rentals         NaN
# 461                          LAN Centers         NaN
# 462                  Home Window Tinting         NaN
# 463                         Self Storage         NaN
# 466                      Medical Centers         NaN
# 467                   Pediatric Dentists         NaN
# 468        Drywall Installation & Repair         NaN
# 470                       Internet Cafes         NaN
# 471             Commercial Truck Dealers         NaN
# 472                       Employment Law         NaN
# 475                        Travel Agents         NaN
# 476                   Threading Services         NaN
# 477                   University Housing         NaN
# 478               Dry Cleaning & Laundry         NaN
# 479                           Cigar Bars         NaN
# 480                        Vehicle Wraps         NaN
# 481                         Custom Cakes         NaN
# 482                         Candy Stores         NaN
# 483                        Mobile Phones         NaN
# 487                     Wedding Planning         NaN
# 488                        Guitar Stores         NaN
# 489                     Packing Supplies         NaN
# 490                     Women's Clothing         NaN
# 492                     Historical Tours         NaN
# 493                      Skilled Nursing         NaN
# 495                         Aerial Tours         NaN
# 496                             Backshop         NaN
# 497                   Lactation Services         NaN
# 498                            Tiki Bars         NaN
# 499                     Persian\/Iranian         NaN
# 500                            RV Rental         NaN
# 502                           Pool Halls         NaN
# 503                        Henna Artists         NaN
# 504                Nurseries & Gardening         NaN
# 505                            Bus Tours         NaN
# 508                        Arts & Crafts         NaN
# 509                       Specialty Food         NaN
# 510                          Strip Clubs         NaN
# 511                 Amateur Sports Teams         NaN
# 512                   Striptease Dancers         NaN
# 513            Event Planning & Services         NaN
# 515                            Pan Asian         NaN
# 517                 Solar Panel Cleaning         NaN
# 519         Traditional Chinese Medicine         NaN
# 520                   Meditation Centers         NaN
# 521                 Debt Relief Services         NaN
# 522               Junk Removal & Hauling         NaN
# 523              Home & Rental Insurance         NaN
# 524                       Graphic Design         NaN
# 526                        Tobacco Shops         NaN
# 528                          Sports Wear         NaN
# 530                     Kids Hair Salons         NaN
# 532                       Used Bookstore         NaN
# 533                        Home & Garden         NaN
# 535                  Property Management         NaN
# 537                             Pub Food         NaN
# 539                  Appliances & Repair         NaN
# 540                     Packing Services         NaN
# 541                       Swimming Pools         NaN
# 542                      Office Cleaning         NaN
# 543                      Shades & Blinds         NaN
# 544                      Teeth Whitening         NaN
# 547                          Formal Wear         NaN
# 548                            RV Repair         NaN
# 550                           Tapas Bars         NaN
# 551                           Bus Rental         NaN
# 552               Medical Transportation         NaN
# 554                     Military Surplus         NaN
# 555                       Live\/Raw Food         NaN
# 556                          Paint & Sip         NaN
# 557                       Latin American         NaN
# 558                     Shopping Centers         NaN
# 559                      Performing Arts         NaN
# 561                           RV Dealers         NaN
# 562                      Travel Services         NaN
# 563                   Nurse Practitioner         NaN
# 564                 Software Development         NaN
# 566                      Amusement Parks         NaN
# 567                          Beer Garden         NaN
# 570                             Colonics         NaN
# 571                          Shoe Stores         NaN
# 573                         Pet Adoption         NaN
# 574           Counseling & Mental Health         NaN
# 576                     Home Health Care         NaN
# 577              Tenant and Eviction Law         NaN
# 578               Food Delivery Services         NaN
# 579                Banks & Credit Unions         NaN
# 581                     Knife Sharpening         NaN
# 582                   Financial Services         NaN
# 583           Internet Service Providers         NaN
# 585                    Installment Loans         NaN
# 586                 Occupational Therapy         NaN
# 587                     Service Stations         NaN
# 589               Auto Electric Services         NaN
# 592                       Jewelry Repair         NaN
# 593                             RV Parks         NaN
# 595                Patisserie\/Cake Shop         NaN
# 598               Video\/Film Production         NaN
# 599                    Knitting Supplies         NaN
# 600                     Town Car Service         NaN
# 601     Landmarks & Historical Buildings         NaN
# 603                         Health Coach         NaN
# 605                     Office Equipment         NaN
# 607                           Pawn Shops         NaN
# 608                     Pool & Billiards         NaN
# 609                      Gutter Services         NaN
# 610                        Beauty & Spas         NaN
# 611                   Emergency Medicine         NaN
# 612                    Department Stores         NaN
# 613                    Specialty Schools         NaN
# 614                  Adult Entertainment         NaN
# 615                      Pain Management         NaN
# 616         Check Cashing\/Pay-day Loans         NaN
# 618                        Dance Studios         NaN
# 619       Musical Instruments & Teachers         NaN
# 622                 Pole Dancing Classes         NaN
# 623                         Endodontists         NaN
# 624                     Mortgage Lenders         NaN
# 625                          Art Museums         NaN
# 626                 Criminal Defense Law         NaN
# 628                          Oxygen Bars         NaN
# 629  Mobility Equipment Sales & Services         NaN
# 630                     Health & Medical         NaN
# 632                     Fire Departments         NaN
# 634        Recording & Rehearsal Studios         NaN
# 635                      Massage Therapy         NaN
# 638                     Trampoline Parks         NaN
# 639                        Periodontists         NaN
# 640                             Go Karts         NaN
# 641                         Pet Boarding         NaN
# 642                      Eyelash Service         NaN
# 646                       Trailer Rental         NaN
# 647                     Mortgage Brokers         NaN
# 649                        Country Clubs         NaN
# 650                          Nail Salons         NaN
# 651                       Haunted Houses         NaN
# 653                         Tax Services         NaN
# 654                           Car Buyers         NaN
# 656                        Dance Schools         NaN
# 657               Furniture Reupholstery         NaN
# 658                   Concierge Medicine         NaN
# 659                      Interior Design         NaN
# 661                   Furniture Assembly         NaN
# 662                            Art Tours         NaN
# 664               Newspapers & Magazines         NaN
# 666                         Music & DVDs         NaN
# 667                    Event Photography         NaN
# 668                     Furniture Stores         NaN
# 671                         Pop-up Shops         NaN
# 674                    Keys & Locksmiths         NaN
# 675                  Children's Clothing         NaN
# 676                        Outlet Stores         NaN
# 678                          Race Tracks         NaN
# 679                 Commissioned Artists         NaN
# 680           Videos & Video Game Rental         NaN
# 681                        Popcorn Shops         NaN
# 682                  Brazilian Jiu-jitsu         NaN
# 684                    Career Counseling         NaN
# 685                          Guns & Ammo         NaN
# 687                        Home Services         NaN
# 688                         Water Stores         NaN
# 690               Blow Dry\/Out Services         NaN
# 691                          Hookah Bars         NaN
# 693                   Cremation Services         NaN
# 694                       Window Washing         NaN
# 695                         Watch Repair         NaN
# 696               Commercial Real Estate         NaN
# 697                  Demolition Services         NaN
# 698                          Hobby Shops         NaN
# 700                           Boat Tours         NaN
# 702                       Japanese Curry         NaN
# 703                 Golf Equipment Shops         NaN
# 704               Interval Training Gyms         NaN
# 705                            Irish Pub         NaN
# 706                  Roadside Assistance         NaN
# 707                         Paint Stores         NaN
# 708                    Party Bus Rentals         NaN
# 709                          Active Life         NaN
# 710                             Beer Bar         NaN
# 712                        Home Cleaning         NaN
# 713                    Cosmetic Surgeons         NaN
# 714                      Scooter Rentals         NaN
# 715                         Pest Control         NaN
# 718                          Skate Shops         NaN
# 720                         Jazz & Blues         NaN
# 722                 Hong Kong Style Cafe         NaN
# 724                  Conveyor Belt Sushi         NaN
# 726                    Gun\/Rifle Ranges         NaN
# 727                   Damage Restoration         NaN
# 732                 Chocolatiers & Shops         NaN
# 733                       Farmers Market         NaN
# 734                       Auction Houses         NaN
# 736                       Bankruptcy Law         NaN
# 738                         Trophy Shops         NaN
# 739                           Beach Bars         NaN
# 740                    Speech Therapists         NaN
# 741                        Auto Security         NaN
# 742            Music Production Services         NaN
# 743                  Smog Check Stations         NaN
# 744                  Personal Assistants         NaN
# 745                   Cards & Stationery         NaN
# 746                Professional Services         NaN
# 747                     Hockey Equipment         NaN
# 748                           Food Tours         NaN
# 749                     Tutoring Centers         NaN
# 751            Cosmetics & Beauty Supply         NaN
# 752                        Oral Surgeons         NaN
# 753                Venues & Event Spaces         NaN
# 754             Health Insurance Offices         NaN
# 755                            Dog Parks         NaN
# 757                            Dive Bars         NaN
# 759                         Summer Camps         NaN
# 760                    Security Services         NaN
# 761              Insulation Installation         NaN
# 762                       Chimney Sweeps         NaN
# 764                 Real Estate Services         NaN
# 767                    Cosmetic Dentists         NaN
# 769                     Floral Designers         NaN
# 770                            Soul Food         NaN
# 771                    Special Education         NaN
# 773        Obstetricians & Gynecologists         NaN
# 774                      Mountain Biking         NaN
# 777                             Gay Bars         NaN
# 778                    Personal Shopping         NaN
# 779    Water Heater Installation\/Repair         NaN
# 780                       Spine Surgeons         NaN
# 781                   College Counseling         NaN
# 782                       American (New)         NaN
# 788                    Printing Services         NaN
# 791                  Personal Injury Law         NaN
# 793                       Party Supplies         NaN
# 796                      Mailbox Centers         NaN
# 797                    Hair Loss Centers         NaN
# 798                  Cosmetology Schools         NaN
# 800                         Comfort Food         NaN
# 801                              Hot Pot         NaN
# 802                     Airport Shuttles         NaN
# 804               Hypnosis\/Hypnotherapy         NaN
# 805                      Walk-in Clinics         NaN
# 806                 Sewing & Alterations         NaN
# 807                       Trailer Repair         NaN
# 808               American (Traditional)         NaN
# 809                        Walking Tours         NaN
# 810                    Behavior Analysts         NaN
# 811                       Local Services         NaN
# 812                             Car Wash         NaN
# 813                Vintage & Consignment         NaN
# 815                        Thrift Stores         NaN
# 816               Emergency Pet Hospital         NaN
# 817             Laser Eye Surgery\/Lasik         NaN
# 818                     Vacation Rentals         NaN
# 819              Car Stereo Installation         NaN
# 820        Departments of Motor Vehicles         NaN
# 821                         Truck Rental         NaN
# 822                           Web Design         NaN
# 823                     Public Relations         NaN
# 824                              Tex-Mex         NaN
# 825                      Home Automation         NaN
# 826                   Electronics Repair         NaN
# 827                  Business Consulting         NaN
# 828                Registration Services         NaN
# 829                            Mini Golf         NaN
# 831                         IV Hydration         NaN
# 832                         Pet Breeders         NaN
# 833                    Building Supplies         NaN
# 834                          Food Trucks         NaN
# 835                           Bubble Tea         NaN
# 837                         Dry Cleaning         NaN
# 838                    Botanical Gardens         NaN
# 839                         Whiskey Bars         NaN
# 840                     Hot Air Balloons         NaN
# 841                     Vehicle Shipping         NaN
# 842                        Cocktail Bars         NaN
# 843                     Fruits & Veggies         NaN
# 845                     Recycling Center         NaN
# 848                           Public Art         NaN
# 849             Fire Protection Services         NaN
# 850                   Business Financing         NaN
# 851                       Powder Coating         NaN
# 852                    Challenge Courses         NaN
# 854                 Chinese Martial Arts         NaN
# 855                      Private Schools         NaN
# 856                            Float Spa         NaN
# 859                    Motorcycle Rental         NaN
# 860                       Champagne Bars         NaN
# 861                      Home Inspectors         NaN
# 863                           Shoe Shine         NaN
# 864                        Face Painting         NaN
# 865                        Skating Rinks         NaN
# 867                         Puerto Rican         NaN
# 869                         Home Staging         NaN
# 870                     Pressure Washers         NaN
# 874                     Security Systems         NaN
# 875                Public Transportation         NaN
# 876                              Tax Law         NaN
# 878                  Himalayan\/Nepalese         NaN
# 879                        Art Galleries         NaN
# 880                          Real Estate         NaN
# 882                   Mobile Dent Repair         NaN
# 883                   Convenience Stores         NaN
# 884                        Music & Video         NaN
# 886                          Comic Books         NaN
# 887                   Bartending Schools         NaN
# 888                       Sex Therapists         NaN
# 889                          CPR Classes         NaN
# 890                            Creperies         NaN
# 891               Vitamins & Supplements         NaN
# 893                           Head Shops         NaN
# 894        Community Service\/Non-Profit         NaN
# 897                          Poutineries         NaN
# 898                      Kids Activities         NaN
# 900                         Contract Law         NaN
# 901                        Scooter Tours         NaN
# 903                     Permanent Makeup         NaN
# 906              Virtual Reality Centers         NaN
# 907                  Session Photography         NaN
# 910                    Motorcycle Repair         NaN
# 911                Private Investigation         NaN
# 912                          Food Stands         NaN
# 915                      Auto Upholstery         NaN
# 917                       Cannabis Tours         NaN
# 918                        Pool Cleaners         NaN
# 919                       Auto Insurance         NaN
# 920                          Pasta Shops         NaN
# 921                     Furniture Rental         NaN
# 922                  Cannabis Collective         NaN
# 923                    Rafting\/Kayaking         NaN
# 924                       Hot Tub & Pool         NaN
# 925                          Skate Parks         NaN
# 926                    Basketball Courts         NaN
# 927                       Beverage Store         NaN
# 928                        Bail Bondsmen         NaN
# 929                      Stucco Services         NaN
# 931                     Medical Supplies         NaN
# 932                           Shaved Ice         NaN
# 935     Windshield Installation & Repair         NaN
# 936                         Comedy Clubs         NaN
# 938                          Pet Sitting         NaN
# 939             Workers Compensation Law         NaN
# 940             Hazardous Waste Disposal         NaN
# 943                              DUI Law         NaN
# 944          Musical Instrument Services         NaN
# 946                   Wheel & Rim Repair         NaN
# 947                  Auto Glass Services         NaN
# 948                           & Probates         NaN

# %%
#We will use these categories as the top, and the rest on 2 "Others" groups
#Top similarity categories
top_c = list(df_similarity.sort_values(by='Similarity',ascending=False)['Categories'].head(14))
#Split into two groups
top_c1 = top_c[:int(len(top_c)/2)]
top_c2 = top_c[int(len(top_c)/2):]

#low similarity (or all other) split into 2 groups
low_c = list(df_similarity.sort_values(by='Similarity',ascending=False)['Categories'].tail(df_similarity.shape[0]-14))

#Pop the restaurants category
low_c.remove('Restaurants')

#Create the category boolean for "other", low and up
df_categories['other_low'] = df_categories[low_c1].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)
df_categories['other_up'] = df_categories[low_c2].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)

#Create categories for top
df_categories['top'] = df_categories[top_c].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)

#Rewrite the other categories with zero if first category if the business is already captured in the "top"
df_categories['other_low'] = np.select([(df_categories['top'] == 1) & (df_categories['other_low'] == 1),
                                        (df_categories['top'] == 1) & (df_categories['other_low'] == 0),
                                        (df_categories['top'] == 0) & (df_categories['other_low'] == 1),
                                        (df_categories['top'] == 0) & (df_categories['other_low'] == 0)],
                                       [0,0,1,0],
                                       default = 0)

df_categories['other_up'] = np.select([(df_categories['top'] == 1) & (df_categories['other_up'] == 1),
                                        (df_categories['top'] == 1) & (df_categories['other_up'] == 0),
                                        (df_categories['top'] == 0) & (df_categories['other_up'] == 1),
                                        (df_categories['top'] == 0) & (df_categories['other_up'] == 0)],
                                       [0,0,1,0],
                                       default = 0)

df_categories['other_up'] = np.select([(df_categories['other_low'] == 1) & (df_categories['other_up'] == 1),
                                       (df_categories['other_low'] == 1) & (df_categories['other_up'] == 0),
                                       (df_categories['other_low'] == 0) & (df_categories['other_up'] == 1),
                                       (df_categories['other_low'] == 0) & (df_categories['other_up'] == 0)],
                                      [0,0,1,0],
                                      default = 0)

#Convert everything to float
df_categories = df_categories.astype(float)

# %%
#Display the list of bins to include in the model
['other_low'] + top_c1 + ['Restaurants'] + top_c2 +['other_up']
# Out:
# ['other_low',
#  'Soup',
#  'Propane',
#  'Tiling',
#  'Cuban',
#  'Turkish',
#  'Vietnamese',
#  'Used',
#  'Restaurants',
#  'Pediatricians',
#  'Argentine',
#  'Mexican',
#  'Food',
#  'Ramen',
#  'Bowling',
#  'Siding',
#  'other_up']

# %%
#Visualize the other low and other up vectors (there should be no overlap)
df_categories[['top','other_low','other_up']].head(20)
# Out:
#                         top  other_low  other_up
# business_id
# iojTeSaoPuxm4WeCzDUA6w  0.0        1.0       0.0
# Qwt9lOpplBAZ7JBrgAqI7g  0.0        1.0       0.0
# R3rss9fkfJxiOK6DueON3w  0.0        1.0       0.0
# kANF0dbeoW34s2vwh6Umfw  1.0        0.0       0.0
# gas3YSrKkEcBliUHhnOLTg  0.0        1.0       0.0
# PL9xKgFL9FB8wDQ9AKrm4g  0.0        1.0       0.0
# faixHjogPjNUo07T0RBRFw  0.0        0.0       1.0
# bJP4l_BGq2CudEu0m-wNjg  0.0        1.0       0.0
# Ik-vXB7HCwnC44KDf_nwdw  0.0        1.0       0.0
# v7ZFEEqJBg_r8NCwHRP_2A  1.0        0.0       0.0
# 6fPQJq4f_yiq1NHn0fd11Q  0.0        1.0       0.0
# k-dDZvTeLysoJvjHI-qr9g  0.0        1.0       0.0
# 1Oa6PpE1MYDT8OLRm8SBig  0.0        1.0       0.0
# 4n81G-pmC3rfhmaPsbwYKg  1.0        0.0       0.0
# PWjgwphd2prhtqTPWwLbXw  1.0        0.0       0.0
# qNChnVaoWDS-RFd9NDBPEA  0.0        1.0       0.0
# uZuh51lXu7tsrC8RAwkg1A  0.0        1.0       0.0
# -ucQnELMVRIUOi3-Kv5r0Q  0.0        1.0       0.0
# _pBXtjN43eqMV0XZTz7nmw  0.0        1.0       0.0
# ci3xUs8ZffvGhWfoioAL0Q  1.0        0.0       0.0

# %% [markdown]
# ### Script of the data architecture<a id="da"></a>
#
# In this section the code to create the data architecture for the CNN is detailed. The steps it follows are:
#
#    - **(1) Define bins:** Define category and distance bins as lists to compose the "x" and "y" axis of each businesses grid.
#    - **(2) Select features:** Select the features to include in the "feature array".
#    - **(3) Loop through bins to create a numpy array witht he desired architecture** Loops through the criteria defined on steps (1) and (2) and stores a numpy array with the desired 4D architecture.

# %%
#Define categories to loop on
categories = ['other_low'] + top_c1 + ['Restaurants'] + top_c2 + ['other_up']

#Define distances to loop on
dist_lst = [
    [5000,int(np.max(distances))],
    [2500,5000],
    [1000,2500],
    [500,1000],
    [250,500],
    [100,250],
    [50,100],
    [0,50],
    [-50,0],
    [-100,-50],
    [-250,-100],
    [-500,-250],
    [-1000,-500],
    [-2500,-1000],
    [-5000,-2500],
    [int(np.min(distances)),-5000]
]

#Define features to loop on
features = ['stars','rev_stars','cool','funny','useful','positive_comments','negative_comments','age','polarity','subjectivity'] 

#Define empty arrays
All = np.empty((distances.shape[0],0)) #For inner loop on cat and distance

#Extract category boolean vector for each category
for cat in categories:
    category = np.array(df_categories[cat]) #Create numpy array
    category = np.tile(category,(distances.shape[0],1)) #Reshape as distances martix
    
    #Loop through distance bins to create distance and category mask
    for dist in dist_lst:
        distance_mask = (distances >= dist[0]) & (distances < dist[1])
        mask = np.multiply(distance_mask,category)
        
        #Loop through features to apply such calculation to the mask
        for feature in features:
            stars = np.tile(df[feature].values,(distances.shape[0],1))
            values = np.multiply(mask,stars)
            values[values==0]=np.nan
            means = np.nan_to_num(np.nanmean(values[:,:],axis=1))
            means = np.where(means!=0,means - df[feature].values,0)
            means = means.reshape(means.shape[0],1)
            
            #Assign to values unique array
            All = np.concatenate((All, means),axis=1)
  
#Reshape all the array into the right format for the CNN
All = All.reshape((distances.shape[0],
                   len(categories),
                   len(dist_lst),
                   len(features)))
# Out:
# C:\Users\roflo\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: Mean of empty slice

# %%
#Lets inspect the shape
All.shape
# Out:
# (8527, 17, 16, 10)

# %%
#Save the dataset
np.save('cnn_dataset_rest',All)

#Save the target variable
np.save('target_rest',df['is_closed'].values)

#Save the observation's id
np.save('ids_rest',np.array(df.index))

#Save the Main category id (Restaurants) - used for masking this specific business category in the modelling process
np.save('rest_category',df_categories['Restaurants'].values)

# %% [markdown]
# **The script above loops over restaurants as the main category of interest**
# The scripts that follow loop through other categories of interest such as "Food", "Bars, and "Shopping".

# %%
#Get list of categories
categories = []
for x in df['categories']:
    if type(x)==float:
        continue
    else:
        categories.extend(x.split(','))

#Clean white spaces
categories = [x.strip() for x in categories]
#Create a list with unique items
categories = [str(x) for x in set(categories)] 

#Compute similarity
similarity = []
for x in categories:
    try:
        similarity.append([x,model.n_similarity('food',[x.replace('&','').lower()])])
    except:
        similarity.append([x,'NaN'])

#Store in a dataframe
df_similarity = pd.DataFrame(similarity,
                             columns=['Categories','Similarity'])

df_similarity['Similarity'] = df_similarity['Similarity'].astype(float)

#We will use these categories as the top, and the rest on 2 "Others" groups
#Top similarity categories
top_c = list(df_similarity.sort_values(by='Similarity',ascending=False)['Categories'].head(14))
#Split into two groups
top_c1 = top_c[:int(len(top_c)/2)]
top_c2 = top_c[int(len(top_c)/2):]

#low similarity (or all other) split into 2 groups
low_c = list(df_similarity.sort_values(by='Similarity',ascending=False)['Categories'].tail(df_similarity.shape[0]-14))

#Pop the restaurants category
low_c.remove('Food')

#Create the category boolean for "other", low and up
df_categories['other_low'] = df_categories[low_c1].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)
df_categories['other_up'] = df_categories[low_c2].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)

#Create categories for top
df_categories['top'] = df_categories[top_c].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)

#Rewrite the other categories with zero if first category if the business is already captured in the "top"
df_categories['other_low'] = np.select([(df_categories['top'] == 1) & (df_categories['other_low'] == 1),
                                        (df_categories['top'] == 1) & (df_categories['other_low'] == 0),
                                        (df_categories['top'] == 0) & (df_categories['other_low'] == 1),
                                        (df_categories['top'] == 0) & (df_categories['other_low'] == 0)],
                                       [0,0,1,0],
                                       default = 0)

df_categories['other_up'] = np.select([(df_categories['top'] == 1) & (df_categories['other_up'] == 1),
                                        (df_categories['top'] == 1) & (df_categories['other_up'] == 0),
                                        (df_categories['top'] == 0) & (df_categories['other_up'] == 1),
                                        (df_categories['top'] == 0) & (df_categories['other_up'] == 0)],
                                       [0,0,1,0],
                                       default = 0)

df_categories['other_up'] = np.select([(df_categories['other_low'] == 1) & (df_categories['other_up'] == 1),
                                       (df_categories['other_low'] == 1) & (df_categories['other_up'] == 0),
                                       (df_categories['other_low'] == 0) & (df_categories['other_up'] == 1),
                                       (df_categories['other_low'] == 0) & (df_categories['other_up'] == 0)],
                                      [0,0,1,0],
                                      default = 0)

#Convert everything to float
df_categories = df_categories.astype(float)

#Define categories to loop on
categories = ['other_low'] + top_c1 + ['Food'] + top_c2 + ['other_up']

#Define distances to loop on
dist_lst = [
    [5000,int(np.max(distances))],
    [2500,5000],
    [1000,2500],
    [500,1000],
    [250,500],
    [100,250],
    [50,100],
    [0,50],
    [-50,0],
    [-100,-50],
    [-250,-100],
    [-500,-250],
    [-1000,-500],
    [-2500,-1000],
    [-5000,-2500],
    [int(np.min(distances)),-5000]
]

#Define features to loop on
features = ['stars','rev_stars','cool','funny','useful','positive_comments','negative_comments','age','polarity','subjectivity'] 

#Define empty arrays
All = np.empty((distances.shape[0],0)) #For inner loop on cat and distance

#Extract category boolean vector for each category
for cat in categories:
    category = np.array(df_categories[cat]) #Create numpy array
    category = np.tile(category,(distances.shape[0],1)) #Reshape as distances martix
    
    #Loop through distance bins to create distance and category mask
    for dist in dist_lst:
        distance_mask = (distances >= dist[0]) & (distances < dist[1])
        mask = np.multiply(distance_mask,category)
        
        #Loop through features to apply such calculation to the mask
        for feature in features:
            stars = np.tile(df[feature].values,(distances.shape[0],1))
            values = np.multiply(mask,stars)
            values[values==0]=np.nan
            means = np.nan_to_num(np.nanmean(values[:,:],axis=1))
            means = np.where(means!=0,means - df[feature].values,0)
            means = means.reshape(means.shape[0],1)
            
            #Assign to values unique array
            All = np.concatenate((All, means),axis=1)
  
#Reshape all the array into the right format for the CNN
All = All.reshape((distances.shape[0],
                   len(categories),
                   len(dist_lst),
                   len(features)))

#Save the dataset
np.save('cnn_dataset_food',All)

#Save the target variable
np.save('target_food',df['is_closed'].values)

#Save the observation's id
np.save('ids_food',np.array(df.index))

#Save the Main category id (Restaurants)
np.save('food_category',df_categories['Food'].values)
# Out:
# C:\Users\roflo\Anaconda3\lib\site-packages\ipykernel_launcher.py:117: RuntimeWarning: Mean of empty slice

# %% [markdown]
# Adding Bars ...

# %%
#Get list of categories
categories = []
for x in df['categories']:
    if type(x)==float:
        continue
    else:
        categories.extend(x.split(','))

#Clean white spaces
categories = [x.strip() for x in categories]
#Create a list with unique items
categories = [str(x) for x in set(categories)] 

#Compute similarity
similarity = []
for x in categories:
    try:
        similarity.append([x,model.n_similarity('bar',[x.replace('&','').lower()])])
    except:
        similarity.append([x,'NaN'])

#Store in a dataframe
df_similarity = pd.DataFrame(similarity,
                             columns=['Categories','Similarity'])

df_similarity['Similarity'] = df_similarity['Similarity'].astype(float)

#We will use these categories as the top, and the rest on 2 "Others" groups
#Top similarity categories
top_c = list(df_similarity.sort_values(by='Similarity',ascending=False)['Categories'].head(14))
#Split into two groups
top_c1 = top_c[:int(len(top_c)/2)]
top_c2 = top_c[int(len(top_c)/2):]

#low similarity (or all other) split into 2 groups
low_c = list(df_similarity.sort_values(by='Similarity',ascending=False)['Categories'].tail(df_similarity.shape[0]-14))

#Pop the restaurants category
low_c.remove('Bars')

#Create the category boolean for "other", low and up
df_categories['other_low'] = df_categories[low_c1].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)
df_categories['other_up'] = df_categories[low_c2].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)

#Create categories for top
df_categories['top'] = df_categories[top_c].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)

#Rewrite the other categories with zero if first category if the business is already captured in the "top"
df_categories['other_low'] = np.select([(df_categories['top'] == 1) & (df_categories['other_low'] == 1),
                                        (df_categories['top'] == 1) & (df_categories['other_low'] == 0),
                                        (df_categories['top'] == 0) & (df_categories['other_low'] == 1),
                                        (df_categories['top'] == 0) & (df_categories['other_low'] == 0)],
                                       [0,0,1,0],
                                       default = 0)

df_categories['other_up'] = np.select([(df_categories['top'] == 1) & (df_categories['other_up'] == 1),
                                        (df_categories['top'] == 1) & (df_categories['other_up'] == 0),
                                        (df_categories['top'] == 0) & (df_categories['other_up'] == 1),
                                        (df_categories['top'] == 0) & (df_categories['other_up'] == 0)],
                                       [0,0,1,0],
                                       default = 0)

df_categories['other_up'] = np.select([(df_categories['other_low'] == 1) & (df_categories['other_up'] == 1),
                                       (df_categories['other_low'] == 1) & (df_categories['other_up'] == 0),
                                       (df_categories['other_low'] == 0) & (df_categories['other_up'] == 1),
                                       (df_categories['other_low'] == 0) & (df_categories['other_up'] == 0)],
                                      [0,0,1,0],
                                      default = 0)

#Convert everything to float
df_categories = df_categories.astype(float)

#Define categories to loop on
categories = ['other_low'] + top_c1 + ['Bars'] + top_c2 + ['other_up']

#Define distances to loop on
dist_lst = [
    [5000,int(np.max(distances))],
    [2500,5000],
    [1000,2500],
    [500,1000],
    [250,500],
    [100,250],
    [50,100],
    [0,50],
    [-50,0],
    [-100,-50],
    [-250,-100],
    [-500,-250],
    [-1000,-500],
    [-2500,-1000],
    [-5000,-2500],
    [int(np.min(distances)),-5000]
]

#Define features to loop on
features = ['stars','rev_stars','cool','funny','useful','positive_comments','negative_comments','age','polarity','subjectivity'] 

#Define empty arrays
All = np.empty((distances.shape[0],0)) #For inner loop on cat and distance

#Extract category boolean vector for each category
for cat in categories:
    category = np.array(df_categories[cat]) #Create numpy array
    category = np.tile(category,(distances.shape[0],1)) #Reshape as distances martix
    
    #Loop through distance bins to create distance and category mask
    for dist in dist_lst:
        distance_mask = (distances >= dist[0]) & (distances < dist[1])
        mask = np.multiply(distance_mask,category)
        
        #Loop through features to apply such calculation to the mask
        for feature in features:
            stars = np.tile(df[feature].values,(distances.shape[0],1))
            values = np.multiply(mask,stars)
            values[values==0]=np.nan
            means = np.nan_to_num(np.nanmean(values[:,:],axis=1))
            means = np.where(means!=0,means - df[feature].values,0)
            means = means.reshape(means.shape[0],1)
            
            #Assign to values unique array
            All = np.concatenate((All, means),axis=1)
  
#Reshape all the array into the right format for the CNN
All = All.reshape((distances.shape[0],
                   len(categories),
                   len(dist_lst),
                   len(features)))

#Save the dataset
np.save('cnn_dataset_bars',All)

#Save the target variable
np.save('target_bars',df['is_closed'].values)

#Save the observation's id
np.save('ids_bars',np.array(df.index))

#Save the Main category id (Restaurants)
np.save('bars_category',df_categories['Bars'].values)
# Out:
# C:\Users\roflo\Anaconda3\lib\site-packages\ipykernel_launcher.py:117: RuntimeWarning: Mean of empty slice

# %% [markdown]
# Adding Shopping ...

# %%
#Get list of categories
categories = []
for x in df['categories']:
    if type(x)==float:
        continue
    else:
        categories.extend(x.split(','))

#Clean white spaces
categories = [x.strip() for x in categories]
#Create a list with unique items
categories = [str(x) for x in set(categories)] 

#Compute similarity
similarity = []
for x in categories:
    try:
        similarity.append([x,model.n_similarity('shopping',[x.replace('&','').lower()])])
    except:
        similarity.append([x,'NaN'])

#Store in a dataframe
df_similarity = pd.DataFrame(similarity,
                             columns=['Categories','Similarity'])

df_similarity['Similarity'] = df_similarity['Similarity'].astype(float)

#We will use these categories as the top, and the rest on 2 "Others" groups
#Top similarity categories
top_c = list(df_similarity.sort_values(by='Similarity',ascending=False)['Categories'].head(14))
#Split into two groups
top_c1 = top_c[:int(len(top_c)/2)]
top_c2 = top_c[int(len(top_c)/2):]

#low similarity (or all other) split into 2 groups
low_c = list(df_similarity.sort_values(by='Similarity',ascending=False)['Categories'].tail(df_similarity.shape[0]-14))

#Pop the restaurants category
low_c.remove('Shopping')

#Create the category boolean for "other", low and up
df_categories['other_low'] = df_categories[low_c1].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)
df_categories['other_up'] = df_categories[low_c2].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)

#Create categories for top
df_categories['top'] = df_categories[top_c].fillna(0).sum(axis=1).apply(lambda x: 1 if x>0 else 0)

#Rewrite the other categories with zero if first category if the business is already captured in the "top"
df_categories['other_low'] = np.select([(df_categories['top'] == 1) & (df_categories['other_low'] == 1),
                                        (df_categories['top'] == 1) & (df_categories['other_low'] == 0),
                                        (df_categories['top'] == 0) & (df_categories['other_low'] == 1),
                                        (df_categories['top'] == 0) & (df_categories['other_low'] == 0)],
                                       [0,0,1,0],
                                       default = 0)

df_categories['other_up'] = np.select([(df_categories['top'] == 1) & (df_categories['other_up'] == 1),
                                        (df_categories['top'] == 1) & (df_categories['other_up'] == 0),
                                        (df_categories['top'] == 0) & (df_categories['other_up'] == 1),
                                        (df_categories['top'] == 0) & (df_categories['other_up'] == 0)],
                                       [0,0,1,0],
                                       default = 0)

df_categories['other_up'] = np.select([(df_categories['other_low'] == 1) & (df_categories['other_up'] == 1),
                                       (df_categories['other_low'] == 1) & (df_categories['other_up'] == 0),
                                       (df_categories['other_low'] == 0) & (df_categories['other_up'] == 1),
                                       (df_categories['other_low'] == 0) & (df_categories['other_up'] == 0)],
                                      [0,0,1,0],
                                      default = 0)

#Convert everything to float
df_categories = df_categories.astype(float)

#Define categories to loop on
categories = ['other_low'] + top_c1 + ['Shopping'] + top_c2 + ['other_up']

#Define distances to loop on
dist_lst = [
    [5000,int(np.max(distances))],
    [2500,5000],
    [1000,2500],
    [500,1000],
    [250,500],
    [100,250],
    [50,100],
    [0,50],
    [-50,0],
    [-100,-50],
    [-250,-100],
    [-500,-250],
    [-1000,-500],
    [-2500,-1000],
    [-5000,-2500],
    [int(np.min(distances)),-5000]
]

#Define features to loop on
features = ['stars','rev_stars','cool','funny','useful','positive_comments','negative_comments','age','polarity','subjectivity'] 

#Define empty arrays
All = np.empty((distances.shape[0],0)) #For inner loop on cat and distance

#Extract category boolean vector for each category
for cat in categories:
    category = np.array(df_categories[cat]) #Create numpy array
    category = np.tile(category,(distances.shape[0],1)) #Reshape as distances martix
    
    #Loop through distance bins to create distance and category mask
    for dist in dist_lst:
        distance_mask = (distances >= dist[0]) & (distances < dist[1])
        mask = np.multiply(distance_mask,category)
        
        #Loop through features to apply such calculation to the mask
        for feature in features:
            stars = np.tile(df[feature].values,(distances.shape[0],1))
            values = np.multiply(mask,stars)
            values[values==0]=np.nan
            means = np.nan_to_num(np.nanmean(values[:,:],axis=1))
            means = np.where(means!=0,means - df[feature].values,0)
            means = means.reshape(means.shape[0],1)
            
            #Assign to values unique array
            All = np.concatenate((All, means),axis=1)
  
#Reshape all the array into the right format for the CNN
All = All.reshape((distances.shape[0],
                   len(categories),
                   len(dist_lst),
                   len(features)))

#Save the dataset
np.save('cnn_dataset_shopping',All)

#Save the target variable
np.save('target_shopping',df['is_closed'].values)

#Save the observation's id
np.save('ids_shopping',np.array(df.index))

#Save the Main category id (Restaurants)
np.save('shopping_category',df_categories['Shopping'].values)
# Out:
# C:\Users\roflo\Anaconda3\lib\site-packages\ipykernel_launcher.py:117: RuntimeWarning: Mean of empty slice
